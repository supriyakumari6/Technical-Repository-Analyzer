# %% [markdown]
# <a href="https://colab.research.google.com/github/supriyakumari6/Technical-Repository-Analyzer/blob/main/test1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import requests
import subprocess
import nbformat
import tempfile
from constants import openai_key
from langchain.llms import OpenAI
from langchain import PromptTemplate
from langchain.document_loaders import TextLoader
import glob

# %%
https://github.com/supriyakumari6/Strivers-SDE-Sheet-Challenge

# %%
os.environ["OPENAI_API_KEY"]=openai_key
github_url = input("Enter the GitHub URL of the repository: ")
repo_name = github_url.split("/")[-1]

# %%
local_path="temp_clone"

# %%
repo_name

# %%
subprocess.check_output(['rm', '-rf', local_path])

# %%
try:
    subprocess.run(['git', 'clone', github_url, local_path], check=True)
    print("true")
except subprocess.CalledProcessError as e:
    print(f"Failed to clone repository: {e}")
    print("false")

# %%
def extract_code_cells(notebook_path):
    nb = nbformat.read(notebook_path, nbformat.NO_CONVERT)
    code_cells = []

    for cell in nb.cells:
        if cell.cell_type == 'code':
            source = cell.source.strip()
            code_cells.append(source)

    return code_cells

def format_code_cells(code_cells):
    formatted_code = []

    for code_cell in code_cells:
        formatted_code.append(f"{code_cell}")

    return '\n'.join(formatted_code)

# %%
docs=[]
for filename in os.scandir(local_path):
    if filename.is_file():

        loader = TextLoader(filename)
        x=loader.load()
        docs.append(x[0].page_content)

# %%
type(docs[0])

# %%
import glob

# absolute path to search all text files inside a specific folder
path = r'E:/demos/files_demos/account/*.txt'
files = glob.glob(path)
print(files)

# %%
docs[3][0].page_content

# %%
extensions = ['.py', '.js', '.java', '.c', '.cpp', '.cs', '.go', '.rb', '.php', '.scala', '.html', '.htm','.sh', '.bash', '.sql', '.ipynb']
docs=[]

# %%
len(docs)

# %%
def is_float(string):
    try:
        float(string)
        return True
    except ValueError:
        return False

# %%
complexity=0.0
newtemp=prompt.format(code=docs[3][0].page_content)
llm=OpenAI(temperature=0.5)
result=llm(newtemp)
if(is_float(result)):
    val=(float)(result)
    complexity+=val

# %%
complexity

# %%
complexity=0.0
for f in docs:
    newtemp=prompt.format(code=f[0].page_content)
    llm=OpenAI(temperature=0.5)
    result=llm(newtemp)
    if(is_float(result)):
        val=(float)(result)
        complexity+=val

# %%
complexity

# %%
str='''
My name is Supriya
this is my code.
I am god

U r god too
'''
print(str)

# %%
complex={}
complex[repo_name]=complexity
complex

# %%
docs=[]
for filename in os.scandir(local_path):  ## this point is remaining
    if filename.is_file():
        print((filename.name))
        try:
            loader = None
            if filename.name.endswith(".ipynb"):
                code_cells = extract_code_cells(filename)
                formatted_code = format_code_cells(code_cells)
                docs.append(formatted_code)
            else:
                loader = TextLoader(filename)
                x=loader.load()
                docs.append(x[0].page_content)
        except Exception as e:
            print("Error loading files with pattern ")
            continue ## till here and then in loop

# %%
print((docs))

# %%
import os
os.makedirs("temp_clone")

# %%
def delete_files_except_extensions(directory, extensions):
    for filename in os.listdir(directory):
        file_path = os.path.join(directory, filename)
        if os.path.isfile(file_path):
            file_extension = os.path.splitext(filename)[1]
            if file_extension not in extensions:
                os.remove(file_path)
                print(f"Deleted: {file_path}")

delete_files_except_extensions(local_path, extensions)
